# %%
import requests
from pprint import pprint

# %%
# VK
main_link = 'https://api.vk.com/method/groups.get'

user_id = '574663897'
token = #место для вашей рекламы
v = '5.110'

param = {'access_token': token,
         'user_id': user_id,
         'extended':1,
         'fields':'name', # не в чем суть данного ключа, без него такой же результат
         'count':'3', # если убрать то выведет все сообщества
         'v': v}

response = requests.get(main_link, param)

data = response.json()

#pprint(data)
for _ in data['response']['items']:
    print(_['name'])
# Out:
# localhost
# Лепрозорий
# Библиотека программиста

# %%
# GitHub
main_link = 'https://api.github.com/users/'

def user_name():
    name = input('Введите имя пользователя')
    if name == '':
        return 'aflyk/repos'
    return name + '/repos'

response = requests.get(main_link+user_name())

pprint(response.json())
# Out:
# Введите имя пользователя
# [{'archive_url': 'https://api.github.com/repos/aflyk/hello/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/aflyk/hello/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/aflyk/hello/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/aflyk/hello/branches{/branch}',
#   'clone_url': 'https://github.com/aflyk/hello.git',
#   'collaborators_url': 'https://api.github.com/repos/aflyk/hello/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/aflyk/hello/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/aflyk/hello/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/aflyk/hello/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/aflyk/hello/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/aflyk/hello/contributors',
#   'created_at': '2019-12-29T06:37:03Z',
# ...
